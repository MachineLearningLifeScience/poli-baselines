# %% [markdown]
# # Computing the initial stability and SASA scores

# %% [markdown]
# After downloading and repairing the proteins (check `./downloading_the_data.ipynb`), let's compute and save the initial stability and SASA scores. The output of this notebook is a `csv` file with columns `["pdb_id", "stability", "sasa", "pH"]`

# %%
from pathlib import Path
import json

from poli.core.util.proteins.foldx import FoldxInterface

THIS_DIR = Path().resolve()
working_dir_base = THIS_DIR / "repaired_pdbs"

# Load the pH values
with open(THIS_DIR / "pHs.json", "r") as f:
    pHs = json.load(f)

# %%
foldx = FoldxInterface(working_dir_base)

rows = []
for folder in working_dir_base.iterdir():
    row = {}
    if folder.is_dir():
        # Set the interface to work in the folder
        foldx.working_dir = folder

        # Get the name of the pdb from the folder name
        pdb_name_and_chain = folder.name
        pdb_id, chain = pdb_name_and_chain.split("_")
        row["pdb_id"] = pdb_id
        row["pH"] = pHs[pdb_id.upper()]

        # Compute the stability and SASA
        stability, sasa = foldx.compute_stability_and_sasa(
            pdb_file=folder / f"{pdb_id}_{chain}_Repair.pdb",
            mutations=None,
        )

        row["stability"] = stability
        row["sasa"] = sasa

        rows.append(row)
# Out:
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4hq8_B_Repair.pdb
#
# BackHbond       =               -163.88
# SideHbond       =               -71.95
# Energy_VdW      =               -257.74
# Electro         =               -12.97
# Energy_SolvP    =               328.24
# Energy_SolvH    =               -341.60
# Energy_vdwclash =               5.52
# energy_torsion  =               4.97
# backbone_vdwclash=              53.93
# Entropy_sidec   =               135.57
# Entropy_mainc   =               331.95
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.94
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -37.69
#
# Starting BuildModel
# Reading MB1M;
# Residue to Mutate METB1 has residue index 0
# Mutating residue = METB1 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:21 2023
# Total time spend: 2.50 seconds.
# validated file "4hq8_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 6dej_B_Repair.pdb
#
# BackHbond       =               -166.47
# SideHbond       =               -65.82
# Energy_VdW      =               -257.41
# Electro         =               -11.51
# Energy_SolvP    =               329.14
# Energy_SolvH    =               -337.94
# Energy_vdwclash =               9.64
# energy_torsion  =               4.01
# backbone_vdwclash=              59.58
# Entropy_sidec   =               136.50
# Entropy_mainc   =               342.30
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.74
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -13.56
#
# Starting BuildModel
# Reading MB2M;
# Residue to Mutate METB2 has residue index 0
# Mutating residue = METB2 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:23 2023
# Total time spend: 1.82 seconds.
# validated file "6dej_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4h3l_A_Repair.pdb
#
# BackHbond       =               -168.97
# SideHbond       =               -74.85
# Energy_VdW      =               -257.93
# Electro         =               -15.49
# Energy_SolvP    =               340.30
# Energy_SolvH    =               -338.65
# Energy_vdwclash =               8.67
# energy_torsion  =               6.10
# backbone_vdwclash=              53.83
# Entropy_sidec   =               145.15
# Entropy_mainc   =               326.72
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.10
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -25.60
#
# Starting BuildModel
# Reading VA7V;
# Residue to Mutate VALA7 has residue index 0
# Mutating residue = VALA7 into VAL
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:24 2023
# Total time spend: 0.99 seconds.
# validated file "4h3l_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4eds_B_Repair.pdb
#
# BackHbond       =               -171.69
# SideHbond       =               -67.15
# Energy_VdW      =               -257.48
# Electro         =               -14.34
# Energy_SolvP    =               331.18
# Energy_SolvH    =               -337.92
# Energy_vdwclash =               7.50
# energy_torsion  =               5.12
# backbone_vdwclash=              59.10
# Entropy_sidec   =               140.32
# Entropy_mainc   =               333.38
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.47
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -27.36
#
# Starting BuildModel
# Reading EB3E;
# Residue to Mutate GLUB3 has residue index 0
# Mutating residue = GLUB3 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:27 2023
# Total time spend: 2.33 seconds.
# validated file "4eds_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 6mgh_A_Repair.pdb
#
# BackHbond       =               -117.57
# SideHbond       =               -44.16
# Energy_VdW      =               -179.56
# Electro         =               -7.89
# Energy_SolvP    =               228.84
# Energy_SolvH    =               -240.40
# Energy_vdwclash =               3.75
# energy_torsion  =               2.36
# backbone_vdwclash=              98.71
# Entropy_sidec   =               94.90
# Entropy_mainc   =               230.22
# water bonds     =               0.00
# helix dipole    =               -6.58
# loop_entropy    =               0.00
# cis_bond        =               0.00
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.19
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -35.92
#
# Starting BuildModel
# Reading MA1M;
# Residue to Mutate META1 has residue index 0
# Mutating residue = META1 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:28 2023
# Total time spend: 1.34 seconds.
# validated file "6mgh_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 2vad_A_Repair.pdb
#
# BackHbond       =               -177.06
# SideHbond       =               -67.08
# Energy_VdW      =               -258.88
# Electro         =               -12.57
# Energy_SolvP    =               348.53
# Energy_SolvH    =               -341.31
# Energy_vdwclash =               8.05
# energy_torsion  =               4.72
# backbone_vdwclash=              59.13
# Entropy_sidec   =               139.86
# Entropy_mainc   =               328.39
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = -45.56
# Energy_Ionisation =             0.84
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -69.84
#
# Starting BuildModel
# Reading TA4T;
# Residue to Mutate THRA4 has residue index 0
# Mutating residue = THRA4 into THR
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:30 2023
# Total time spend: 1.33 seconds.
# validated file "2vad_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4jge_B_Repair.pdb
#
# BackHbond       =               -152.06
# SideHbond       =               -68.08
# Energy_VdW      =               -255.27
# Electro         =               -6.22
# Energy_SolvP    =               320.21
# Energy_SolvH    =               -336.58
# Energy_vdwclash =               8.30
# energy_torsion  =               3.87
# backbone_vdwclash=              62.04
# Entropy_sidec   =               132.27
# Entropy_mainc   =               322.16
# water bonds     =               0.00
# helix dipole    =               0.24
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.60
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -27.33
#
# Starting BuildModel
# Reading SB1S;
# Residue to Mutate SERB1 has residue index 0
# Mutating residue = SERB1 into SER
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:31 2023
# Total time spend: 1.48 seconds.
# validated file "4jge_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 5jva_A_Repair.pdb
#
# BackHbond       =               -175.21
# SideHbond       =               -75.19
# Energy_VdW      =               -264.22
# Electro         =               -16.37
# Energy_SolvP    =               345.21
# Energy_SolvH    =               -344.33
# Energy_vdwclash =               10.32
# energy_torsion  =               5.42
# backbone_vdwclash=              61.35
# Entropy_sidec   =               149.99
# Entropy_mainc   =               343.37
# water bonds     =               0.00
# helix dipole    =               -2.01
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.64
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -20.11
#
# Starting BuildModel
# Reading GA1G;
# Residue to Mutate GLYA1 has residue index 0
# Mutating residue = GLYA1 into GLY
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:33 2023
# Total time spend: 0.95 seconds.
# validated file "5jva_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4edo_B_Repair.pdb
#
# BackHbond       =               -171.23
# SideHbond       =               -69.26
# Energy_VdW      =               -259.66
# Electro         =               -16.14
# Energy_SolvP    =               335.05
# Energy_SolvH    =               -340.41
# Energy_vdwclash =               8.66
# energy_torsion  =               8.20
# backbone_vdwclash=              62.03
# Entropy_sidec   =               139.88
# Entropy_mainc   =               334.91
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.28
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -26.48
#
# Starting BuildModel
# Reading EB3E;
# Residue to Mutate GLUB3 has residue index 0
# Mutating residue = GLUB3 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:35 2023
# Total time spend: 2.36 seconds.
# validated file "4edo_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3rwa_B_Repair.pdb
#
# BackHbond       =               -172.87
# SideHbond       =               -76.55
# Energy_VdW      =               -261.56
# Electro         =               -13.64
# Energy_SolvP    =               339.35
# Energy_SolvH    =               -341.62
# Energy_vdwclash =               7.18
# energy_torsion  =               4.51
# backbone_vdwclash=              60.14
# Entropy_sidec   =               147.11
# Entropy_mainc   =               352.79
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.44
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -11.61
#
# Starting BuildModel
# Reading GB1G;
# Residue to Mutate GLYB1 has residue index 0
# Mutating residue = GLYB1 into GLY
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:37 2023
# Total time spend: 0.92 seconds.
# validated file "3rwa_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3nt9_A_Repair.pdb
#
# BackHbond       =               -171.81
# SideHbond       =               -71.99
# Energy_VdW      =               -257.74
# Electro         =               -12.53
# Energy_SolvP    =               342.11
# Energy_SolvH    =               -336.12
# Energy_vdwclash =               9.75
# energy_torsion  =               5.03
# backbone_vdwclash=              58.93
# Entropy_sidec   =               144.25
# Entropy_mainc   =               338.43
# water bonds     =               0.00
# helix dipole    =               -1.86
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.04
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -9.18
#
# Starting BuildModel
# Reading EA3E;
# Residue to Mutate GLUA3 has residue index 0
# Mutating residue = GLUA3 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:39 2023
# Total time spend: 2.54 seconds.
# validated file "3nt9_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4nws_A_Repair.pdb
#
# BackHbond       =               -170.07
# SideHbond       =               -74.91
# Energy_VdW      =               -257.54
# Electro         =               -13.12
# Energy_SolvP    =               343.84
# Energy_SolvH    =               -333.44
# Energy_vdwclash =               14.55
# energy_torsion  =               4.89
# backbone_vdwclash=              64.69
# Entropy_sidec   =               147.02
# Entropy_mainc   =               342.56
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.90
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  6.92
#
# Starting BuildModel
# Reading EA3E;
# Residue to Mutate GLUA3 has residue index 0
# Mutating residue = GLUA3 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:42 2023
# Total time spend: 2.28 seconds.
# validated file "4nws_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 2h5r_A_Repair.pdb
#
# BackHbond       =               -178.69
# SideHbond       =               -71.43
# Energy_VdW      =               -262.81
# Electro         =               -14.84
# Energy_SolvP    =               335.50
# Energy_SolvH    =               -350.16
# Energy_vdwclash =               8.69
# energy_torsion  =               8.82
# backbone_vdwclash=              64.89
# Entropy_sidec   =               142.20
# Entropy_mainc   =               347.77
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.04
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -31.65
#
# Starting BuildModel
# Reading AA6A;
# Residue to Mutate ALAA6 has residue index 0
# Mutating residue = ALAA6 into ALA
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:43 2023
# Total time spend: 0.79 seconds.
# validated file "2h5r_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3pj5_B_Repair.pdb
#
# BackHbond       =               -172.57
# SideHbond       =               -64.74
# Energy_VdW      =               -262.94
# Electro         =               -12.95
# Energy_SolvP    =               336.01
# Energy_SolvH    =               -345.67
# Energy_vdwclash =               5.27
# energy_torsion  =               3.48
# backbone_vdwclash=              58.63
# Entropy_sidec   =               142.86
# Entropy_mainc   =               338.41
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.85
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -29.74
#
# Starting BuildModel
# Reading EB0E;
# Residue to Mutate GLUB0 has residue index 0
# Mutating residue = GLUB0 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:46 2023
# Total time spend: 2.83 seconds.
# validated file "3pj5_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3u0l_A_Repair.pdb
#
# BackHbond       =               -165.44
# SideHbond       =               -65.70
# Energy_VdW      =               -257.25
# Electro         =               -14.86
# Energy_SolvP    =               332.88
# Energy_SolvH    =               -336.77
# Energy_vdwclash =               8.75
# energy_torsion  =               5.88
# backbone_vdwclash=              59.25
# Entropy_sidec   =               138.77
# Entropy_mainc   =               324.30
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.32
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -25.89
#
# Starting BuildModel
# Reading SA3S;
# Residue to Mutate SERA3 has residue index 0
# Mutating residue = SERA3 into SER
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:48 2023
# Total time spend: 1.12 seconds.
# validated file "3u0l_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3nez_A_Repair.pdb
#
# BackHbond       =               -170.55
# SideHbond       =               -67.96
# Energy_VdW      =               -253.48
# Electro         =               -11.15
# Energy_SolvP    =               321.30
# Energy_SolvH    =               -335.70
# Energy_vdwclash =               8.97
# energy_torsion  =               6.15
# backbone_vdwclash=              54.27
# Entropy_sidec   =               134.49
# Entropy_mainc   =               329.88
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.15
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -34.66
#
# Starting BuildModel
# Reading MA5M;
# Residue to Mutate META5 has residue index 0
# Mutating residue = META5 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:50 2023
# Total time spend: 2.24 seconds.
# validated file "3nez_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3m22_A_Repair.pdb
#
# BackHbond       =               -154.74
# SideHbond       =               -67.29
# Energy_VdW      =               -259.17
# Electro         =               -11.18
# Energy_SolvP    =               338.52
# Energy_SolvH    =               -339.10
# Energy_vdwclash =               11.11
# energy_torsion  =               4.12
# backbone_vdwclash=              67.76
# Entropy_sidec   =               142.17
# Entropy_mainc   =               351.75
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.37
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  19.80
#
# Starting BuildModel
# Reading EA3E;
# Residue to Mutate GLUA3 has residue index 0
# Mutating residue = GLUA3 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:52 2023
# Total time spend: 1.98 seconds.
# validated file "3m22_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 5dtl_I_Repair.pdb
#
# BackHbond       =               -157.32
# SideHbond       =               -62.70
# Energy_VdW      =               -253.58
# Electro         =               -12.66
# Energy_SolvP    =               317.18
# Energy_SolvH    =               -338.20
# Energy_vdwclash =               7.87
# energy_torsion  =               5.59
# backbone_vdwclash=              56.23
# Entropy_sidec   =               129.26
# Entropy_mainc   =               324.93
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               3.37
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.54
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -34.71
#
# Starting BuildModel
# Reading SI2S;
# Residue to Mutate SERI2 has residue index 0
# Mutating residue = SERI2 into SER
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:54 2023
# Total time spend: 1.16 seconds.
# validated file "5dtl_I_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3e5t_A_Repair.pdb
#
# BackHbond       =               -169.19
# SideHbond       =               -59.00
# Energy_VdW      =               -265.88
# Electro         =               -13.09
# Energy_SolvP    =               337.85
# Energy_SolvH    =               -349.44
# Energy_vdwclash =               8.98
# energy_torsion  =               3.69
# backbone_vdwclash=              62.81
# Entropy_sidec   =               138.62
# Entropy_mainc   =               346.13
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.13
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -17.96
#
# Starting BuildModel
# Reading MA1M;
# Residue to Mutate META1 has residue index 0
# Mutating residue = META1 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:57 2023
# Total time spend: 2.58 seconds.
# validated file "3e5t_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 7oin_B_Repair.pdb
#
# BackHbond       =               -173.86
# SideHbond       =               -73.38
# Energy_VdW      =               -256.91
# Electro         =               -14.94
# Energy_SolvP    =               350.31
# Energy_SolvH    =               -337.18
# Energy_vdwclash =               4.91
# energy_torsion  =               3.34
# backbone_vdwclash=              57.54
# Entropy_sidec   =               142.21
# Entropy_mainc   =               334.12
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.38
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -17.75
#
# Starting BuildModel
# Reading VB2V;
# Residue to Mutate VALB2 has residue index 0
# Mutating residue = VALB2 into VAL
# Your file run OK
# End time of FoldX: Mon Sep 11 14:57:58 2023
# Total time spend: 0.94 seconds.
# validated file "7oin_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 2h5q_A_Repair.pdb
#
# BackHbond       =               -179.25
# SideHbond       =               -73.25
# Energy_VdW      =               -259.46
# Electro         =               -10.92
# Energy_SolvP    =               332.20
# Energy_SolvH    =               -342.89
# Energy_vdwclash =               6.60
# energy_torsion  =               4.86
# backbone_vdwclash=              59.79
# Entropy_sidec   =               139.68
# Entropy_mainc   =               325.75
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.30
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -53.14
#
# Starting BuildModel
# Reading NA4N;
# Residue to Mutate ASNA4 has residue index 0
# Mutating residue = ASNA4 into ASN
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:00 2023
# Total time spend: 1.57 seconds.
# validated file "2h5q_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 6fzn_A_Repair.pdb
#
# BackHbond       =               -118.40
# SideHbond       =               -36.39
# Energy_VdW      =               -149.74
# Electro         =               -3.88
# Energy_SolvP    =               199.43
# Energy_SolvH    =               -195.09
# Energy_vdwclash =               4.28
# energy_torsion  =               2.22
# backbone_vdwclash=              136.43
# Entropy_sidec   =               84.02
# Entropy_mainc   =               192.55
# water bonds     =               0.00
# helix dipole    =               -6.90
# loop_entropy    =               0.00
# cis_bond        =               0.00
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.57
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -27.32
#
# Starting BuildModel
# Reading KA2K;
# Residue to Mutate LYSA2 has residue index 0
# Mutating residue = LYSA2 into LYS
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:04 2023
# Total time spend: 4.39 seconds.
# validated file "6fzn_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 2vae_D_Repair.pdb
#
# BackHbond       =               -171.30
# SideHbond       =               -72.18
# Energy_VdW      =               -258.83
# Electro         =               -10.45
# Energy_SolvP    =               326.41
# Energy_SolvH    =               -345.22
# Energy_vdwclash =               6.67
# energy_torsion  =               3.59
# backbone_vdwclash=              58.97
# Entropy_sidec   =               141.24
# Entropy_mainc   =               328.46
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.73
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -48.64
#
# Starting BuildModel
# Reading VD7V;
# Residue to Mutate VALD7 has residue index 0
# Mutating residue = VALD7 into VAL
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:06 2023
# Total time spend: 1.07 seconds.
# validated file "2vae_D_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 7zct_B_Repair.pdb
#
# BackHbond       =               -173.14
# SideHbond       =               -77.52
# Energy_VdW      =               -262.55
# Electro         =               -16.36
# Energy_SolvP    =               337.32
# Energy_SolvH    =               -343.09
# Energy_vdwclash =               5.53
# energy_torsion  =               4.82
# backbone_vdwclash=              55.38
# Entropy_sidec   =               145.41
# Entropy_mainc   =               324.63
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.50
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -52.22
#
# Starting BuildModel
# Reading AB7A;
# Residue to Mutate ALAB7 has residue index 0
# Mutating residue = ALAB7 into ALA
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:07 2023
# Total time spend: 0.74 seconds.
# validated file "7zct_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3ir8_B_Repair.pdb
#
# BackHbond       =               -164.66
# SideHbond       =               -68.52
# Energy_VdW      =               -249.86
# Electro         =               -10.36
# Energy_SolvP    =               314.99
# Energy_SolvH    =               -329.35
# Energy_vdwclash =               6.24
# energy_torsion  =               4.35
# backbone_vdwclash=              48.54
# Entropy_sidec   =               131.22
# Entropy_mainc   =               321.93
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.14
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -40.61
#
# Starting BuildModel
# Reading SB2S;
# Residue to Mutate SERB2 has residue index 0
# Mutating residue = SERB2 into SER
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:08 2023
# Total time spend: 0.78 seconds.
# validated file "3ir8_B_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
# ...
# Entropy_sidec   =               143.94
# Entropy_mainc   =               352.90
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.89
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.84
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -0.94
#
# Starting BuildModel
# Reading EA2E;
# Residue to Mutate GLUA2 has residue index 0
# Mutating residue = GLUA2 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:38 2023
# Total time spend: 3.07 seconds.
# validated file "3ip2_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 2vvh_A_Repair.pdb
#
# BackHbond       =               -158.50
# SideHbond       =               -70.08
# Energy_VdW      =               -259.48
# Electro         =               -12.34
# Energy_SolvP    =               335.61
# Energy_SolvH    =               -342.45
# Energy_vdwclash =               5.37
# energy_torsion  =               2.23
# backbone_vdwclash=              59.22
# Entropy_sidec   =               134.42
# Entropy_mainc   =               327.62
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               3.37
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.76
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -32.47
#
# Starting BuildModel
# Reading MA1M;
# Residue to Mutate META1 has residue index 0
# Mutating residue = META1 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:41 2023
# Total time spend: 1.95 seconds.
# validated file "2vvh_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3e5v_A_Repair.pdb
#
# BackHbond       =               -152.49
# SideHbond       =               -62.52
# Energy_VdW      =               -259.51
# Electro         =               -14.73
# Energy_SolvP    =               338.66
# Energy_SolvH    =               -340.69
# Energy_vdwclash =               22.15
# energy_torsion  =               7.58
# backbone_vdwclash=              77.43
# Entropy_sidec   =               136.26
# Entropy_mainc   =               350.54
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.57
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  29.08
#
# Starting BuildModel
# Reading MA1M;
# Residue to Mutate META1 has residue index 0
# Mutating residue = META1 into MET
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:42 2023
# Total time spend: 1.16 seconds.
# validated file "3e5v_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3bxa_A_Repair.pdb
#
# BackHbond       =               -174.94
# SideHbond       =               -72.39
# Energy_VdW      =               -262.33
# Electro         =               -13.52
# Energy_SolvP    =               339.58
# Energy_SolvH    =               -343.03
# Energy_vdwclash =               7.19
# energy_torsion  =               4.21
# backbone_vdwclash=              61.02
# Entropy_sidec   =               147.91
# Entropy_mainc   =               338.15
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.08
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -25.84
#
# Starting BuildModel
# Reading EA3E;
# Residue to Mutate GLUA3 has residue index 0
# Mutating residue = GLUA3 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:44 2023
# Total time spend: 2.26 seconds.
# validated file "3bxa_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 4oqw_A_Repair.pdb
#
# BackHbond       =               -165.07
# SideHbond       =               -60.61
# Energy_VdW      =               -260.49
# Electro         =               -12.75
# Energy_SolvP    =               335.22
# Energy_SolvH    =               -344.21
# Energy_vdwclash =               14.13
# energy_torsion  =               5.64
# backbone_vdwclash=              61.69
# Entropy_sidec   =               144.65
# Entropy_mainc   =               344.67
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             0.83
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  4.26
#
# Starting BuildModel
# Reading GA1G;
# Residue to Mutate GLYA1 has residue index 0
# Mutating residue = GLYA1 into GLY
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:46 2023
# Total time spend: 1.01 seconds.
# validated file "4oqw_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 1xqm_A_Repair.pdb
#
# BackHbond       =               -164.79
# SideHbond       =               -69.03
# Energy_VdW      =               -262.29
# Electro         =               -12.90
# Energy_SolvP    =               338.48
# Energy_SolvH    =               -344.77
# Energy_vdwclash =               12.22
# energy_torsion  =               5.29
# backbone_vdwclash=              66.05
# Entropy_sidec   =               141.16
# Entropy_mainc   =               346.07
# water bonds     =               0.00
# helix dipole    =               -2.22
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.75
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -8.76
#
# Starting BuildModel
# Reading SA3S;
# Residue to Mutate SERA3 has residue index 0
# Mutating residue = SERA3 into SER
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:48 2023
# Total time spend: 1.56 seconds.
# validated file "1xqm_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 3ned_A_Repair.pdb
#
# BackHbond       =               -180.72
# SideHbond       =               -76.95
# Energy_VdW      =               -268.11
# Electro         =               -13.92
# Energy_SolvP    =               375.60
# Energy_SolvH    =               -351.40
# Energy_vdwclash =               6.00
# energy_torsion  =               6.32
# backbone_vdwclash=              65.45
# Entropy_sidec   =               148.38
# Entropy_mainc   =               340.99
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.76
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -9.80
#
# Starting BuildModel
# Reading EA1E;
# Residue to Mutate GLUA1 has residue index 0
# Mutating residue = GLUA1 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:50 2023
# Total time spend: 2.37 seconds.
# validated file "3ned_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 2qlg_A_Repair.pdb
#
# BackHbond       =               -176.61
# SideHbond       =               -75.49
# Energy_VdW      =               -261.97
# Electro         =               -18.24
# Energy_SolvP    =               345.92
# Energy_SolvH    =               -342.00
# Energy_vdwclash =               9.77
# energy_torsion  =               7.65
# backbone_vdwclash=              63.02
# Entropy_sidec   =               147.13
# Entropy_mainc   =               332.60
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.56
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -27.43
#
# Starting BuildModel
# Reading EA6E;
# Residue to Mutate GLUA6 has residue index 0
# Mutating residue = GLUA6 into GLU
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:53 2023
# Total time spend: 2.04 seconds.
# validated file "2qlg_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE
#    ********************************************
#    ***                                      ***
#    ***             FoldX 4 (c)              ***
#    ***                                      ***
#    ***     code by the FoldX Consortium     ***
#    ***                                      ***
#    ***     Jesper Borg, Frederic Rousseau   ***
#    ***    Joost Schymkowitz, Luis Serrano   ***
#    ***    Peter Vanhee, Erik Verschueren    ***
#    ***     Lies Baeten, Javier Delgado      ***
#    ***       and Francois Stricher          ***
#    *** and any other of the 9! permutations ***
#    ***   based on an original concept by    ***
#    ***   Raphael Guerois and Luis Serrano   ***
#    ********************************************
#
# 1 models read: 6xwy_A_Repair.pdb
#
# BackHbond       =               -163.57
# SideHbond       =               -67.81
# Energy_VdW      =               -252.64
# Electro         =               -15.93
# Energy_SolvP    =               326.78
# Energy_SolvH    =               -331.17
# Energy_vdwclash =               6.56
# energy_torsion  =               4.74
# backbone_vdwclash=              58.94
# Entropy_sidec   =               135.54
# Entropy_mainc   =               324.32
# water bonds     =               0.00
# helix dipole    =               0.00
# loop_entropy    =               0.00
# cis_bond        =               2.25
# disulfide       =               0.00
# kn electrostatic=               0.00
# partial covalent interactions = 0.00
# Energy_Ionisation =             1.16
# Entropy Complex =               0.00
# -----------------------------------------------------------
# Total          = 				  -29.78
#
# Starting BuildModel
# Reading PA2P;
# Residue to Mutate PROA2 has residue index 0
# Mutating residue = PROA2 into PRO
# Your file run OK
# End time of FoldX: Mon Sep 11 14:58:54 2023
# Total time spend: 0.84 seconds.
# validated file "6xwy_A_Repair_1.pdb" => successfully finished
# Cleaning BuildModel...DONE

# %% [markdown]
# Let's change the `None`s for `NaN`s

# %%
for row in rows:
    if row["pH"] is None:
        row["pH"] = float("nan")

# %%
rows
# Out:
# [{'pdb_id': '4hq8',
#   'pH': 7.5,
#   'stability': 37.6997,
#   'sasa': 10590.687610794252},
#  {'pdb_id': '6dej',
#   'pH': nan,
#   'stability': 13.5624,
#   'sasa': 11102.123802587561},
#  {'pdb_id': '4h3l',
#   'pH': 6.5,
#   'stability': 25.6074,
#   'sasa': 10051.45979711304},
#  {'pdb_id': '4eds',
#   'pH': 7.0,
#   'stability': 27.3628,
#   'sasa': 10300.85007823728},
#  {'pdb_id': '6mgh',
#   'pH': 4.0,
#   'stability': 35.9202,
#   'sasa': 8224.213615811059},
#  {'pdb_id': '2vad',
#   'pH': 7.6,
#   'stability': 69.8402,
#   'sasa': 10377.771961794057},
#  {'pdb_id': '4jge',
#   'pH': 7.0,
#   'stability': 27.3797,
#   'sasa': 10215.967524560014},
#  {'pdb_id': '5jva',
#   'pH': 8.5,
#   'stability': 20.1138,
#   'sasa': 10901.775592343227},
#  {'pdb_id': '4edo',
#   'pH': 7.0,
#   'stability': 26.4975,
#   'sasa': 10260.716898105311},
#  {'pdb_id': '3rwa',
#   'pH': 7.5,
#   'stability': 11.6063,
#   'sasa': 11660.478524556138},
#  {'pdb_id': '3nt9',
#   'pH': 5.6,
#   'stability': 9.23374,
#   'sasa': 11083.908044134329},
#  {'pdb_id': '4nws',
#   'pH': 3.5,
#   'stability': -6.92015,
#   'sasa': 10895.977984162957},
#  {'pdb_id': '2h5r',
#   'pH': 10.5,
#   'stability': 31.6511,
#   'sasa': 10939.958597419552},
#  {'pdb_id': '3pj5',
#   'pH': 5.0,
#   'stability': 29.7576,
#   'sasa': 10675.523467838313},
#  {'pdb_id': '3u0l',
#   'pH': 4.5,
#   'stability': 25.9861,
#   'sasa': 10227.531400392243},
#  {'pdb_id': '3nez',
#   'pH': 6.5,
#   'stability': 34.8175,
#   'sasa': 10561.265062496168},
#  {'pdb_id': '3m22',
#   'pH': 8.8,
#   'stability': -19.8014,
#   'sasa': 11092.068896538705},
#  {'pdb_id': '5dtl',
#   'pH': 9.0,
#   'stability': 34.7088,
#   'sasa': 11239.016867777627},
#  {'pdb_id': '3e5t',
#   'pH': 4.6,
#   'stability': 18.031,
#   'sasa': 11183.772400787222},
#  {'pdb_id': '7oin',
#   'pH': nan,
#   'stability': 17.8005,
#   'sasa': 11619.311308051798},
#  {'pdb_id': '2h5q',
#   'pH': 8.0,
#   'stability': 53.1727,
#   'sasa': 10590.064645537415},
#  {'pdb_id': '6fzn',
#   'pH': 8.0,
#   'stability': 27.3283,
#   'sasa': 8057.523625009568},
#  {'pdb_id': '2vae',
#   'pH': 7.5,
#   'stability': 48.6442,
#   'sasa': 10757.165141967766},
#  {'pdb_id': '7zct', 'pH': 7.5, 'stability': 52.224, 'sasa': 9976.205596600497},
#  {'pdb_id': '3ir8',
#   'pH': 7.0,
#   'stability': 40.6234,
#   'sasa': 10368.545016205866},
#  {'pdb_id': '3u8c',
#   'pH': 5.5,
#   'stability': -18.6273,
#   'sasa': 10917.008483970101},
#  {'pdb_id': '3p8u',
#   'pH': 8.5,
#   'stability': 13.1521,
#   'sasa': 10914.899520255376},
#  {'pdb_id': '2v4e',
#   'pH': 5.5,
#   'stability': 28.5214,
#   'sasa': 10595.600332854969},
#  {'pdb_id': '3nt3',
#   'pH': 4.5,
#   'stability': 24.6969,
#   'sasa': 11080.96427128695},
#  {'pdb_id': '4kge',
#   'pH': 4.5,
#   'stability': 0.805146,
#   'sasa': 10912.448223472373},
#  {'pdb_id': '1uis',
#   'pH': 4.3,
#   'stability': -6.46876,
#   'sasa': 10903.664581740348},
#  {'pdb_id': '3gb3',
#   'pH': 6.5,
#   'stability': 2.67286,
#   'sasa': 11227.403467878807},
#  {'pdb_id': '1yzw',
#   'pH': nan,
#   'stability': 21.078,
#   'sasa': 10960.753075653818},
#  {'pdb_id': '1zgo',
#   'pH': 7.0,
#   'stability': 37.2865,
#   'sasa': 10741.966481134445},
#  {'pdb_id': '4jf9',
#   'pH': 7.0,
#   'stability': 19.5032,
#   'sasa': 10051.906757783054},
#  {'pdb_id': '5ez2',
#   'pH': 5.5,
#   'stability': 4.32292,
#   'sasa': 9193.977375588744},
#  {'pdb_id': '6aa7', 'pH': nan, 'stability': 40.643, 'sasa': 11168.20754334783},
#  {'pdb_id': '5lk4',
#   'pH': 4.2,
#   'stability': 63.7822,
#   'sasa': 10578.038980717849},
#  {'pdb_id': '3ip2',
#   'pH': 7.0,
#   'stability': 0.955091,
#   'sasa': 11415.060799908733},
#  {'pdb_id': '2vvh',
#   'pH': 8.4,
#   'stability': 32.5131,
#   'sasa': 10830.89141004368},
#  {'pdb_id': '3e5v', 'pH': 4.6, 'stability': -28.984, 'sasa': 11569.8222262364},
#  {'pdb_id': '3bxa',
#   'pH': 4.2,
#   'stability': 25.9125,
#   'sasa': 10862.060884919087},
#  {'pdb_id': '4oqw',
#   'pH': 7.6,
#   'stability': -4.25572,
#   'sasa': 11224.12816904188},
#  {'pdb_id': '1xqm',
#   'pH': 5.7,
#   'stability': 8.7582,
#   'sasa': 10854.350788228649},
#  {'pdb_id': '3ned',
#   'pH': 6.5,
#   'stability': 9.81107,
#   'sasa': 11424.900481728078},
#  {'pdb_id': '2qlg',
#   'pH': 8.5,
#   'stability': 27.4336,
#   'sasa': 10174.011542104952},
#  {'pdb_id': '6xwy',
#   'pH': 8.0,
#   'stability': 29.7796,
#   'sasa': 10507.298809025544}]

# %%
import pandas as pd

df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#   pdb_id   pH  stability          sasa
# 0   4hq8  7.5    37.6997  10590.687611
# 1   6dej  NaN    13.5624  11102.123803
# 2   4h3l  6.5    25.6074  10051.459797
# 3   4eds  7.0    27.3628  10300.850078
# 4   6mgh  4.0    35.9202   8224.213616

# %% [markdown]
# Let's save it, after appending the title it has in `rcsb`:

# %%
import pypdb

df["title"] = df["pdb_id"].apply(lambda pdb_id: pypdb.get_info(pdb_id)["struct"]["title"])

df.to_csv(THIS_DIR / "initial_stability_and_sasa.csv", index=False)

# %% [markdown]
# ## What's the current pareto front?

# %%
from pathlib import Path
import pandas as pd

THIS_DIR = Path().resolve()

df = pd.read_csv(THIS_DIR / "initial_stability_and_sasa.csv")

# %% [markdown]
# Let's do a scatter plot of these stabilities and SASA scores

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns
import numpy as np

import plotly.express as px

import torch

from botorch.utils.multi_objective import pareto

# sns.set_theme(style="whitegrid")


data = df[["sasa", "stability"]].to_numpy()
pareto_mask = pareto.is_non_dominated(torch.from_numpy(data))

df_pareto = df.drop(np.where(~pareto_mask)[0])

fig = px.scatter(df, x="sasa", y="stability", hover_data=["pdb_id", "title"])
fig.show()

print("Pareto front:")
print(df_pareto["title"].values)
# Out:
# Pareto front:
# ['Monomeric red fluorescent protein, DsRed.M1'
#  'Crystal structure of circular-permutated mKate'
#  'Crystal structure of mEos2-A69T fluorescent protein'
#  'Crystal structure of LSSmScarlet - a genetically encoded red fluorescent protein with a large Stokes shift'
#  'Crystal structure of mCherry'
#  'Fast maturing red fluorescent protein, DsRed.T4'
#  'Fluorescent protein from Acropora digitifera'
#  'Structure of the Red Fluorescent Protein mScarlet at pH 7.8']

# %% [markdown]
# ## Saving the pareto front for running `nsga-ii`

# %%
df_pareto.to_csv(THIS_DIR / "initial_pareto_front.csv", index=False)
